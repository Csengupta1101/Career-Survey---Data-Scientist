# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
Data = pd.read_csv('Data Science Career Dataset.csv', encoding ='unicode_escape')

# %%
Data.shape
# Out:
# (430, 3)

# %%
Data.columns
# Out:
# Index(['Job Role', 'Location', 'Skills'], dtype='object')

# %%
Data.head()
# Out:
#               Job Role Location            Skills
# 0  Data Science Intern     Pune           Sklearn
# 1  Data Science Intern     Pune    Data Wrangling
# 2  Data Science Intern     Pune             Keras
# 3  Data Science Intern     Pune           PyTorch
# 4  Data Science Intern     Pune  Machine Learning

# %%
Data.isnull().sum()
# Out:
# Job Role    340
# Location    340
# Skills      340
# dtype: int64

# %%
round(100*(Data.isnull().sum()/len(Data.index)),2)
# Out:
# Job Role    79.07
# Location    79.07
# Skills      79.07
# dtype: float64

# %%
Data.head(430)
# Out:
#                 Job Role Location            Skills
# 0    Data Science Intern     Pune           Sklearn
# 1    Data Science Intern     Pune    Data Wrangling
# 2    Data Science Intern     Pune             Keras
# 3    Data Science Intern     Pune           PyTorch
# 4    Data Science Intern     Pune  Machine Learning
# ..                   ...      ...               ...
# 425                  NaN      NaN               NaN
# 426                  NaN      NaN               NaN
# 427                  NaN      NaN               NaN
# 428                  NaN      NaN               NaN
# 429                  NaN      NaN               NaN
#
# [430 rows x 3 columns]

# %%
print("Number Of Unique Skills:", Data['Skills'].nunique())
# Out:
# Number Of Unique Skills: 65

# %%
Data['Location'] = Data['Location'].replace(('Bangalore'), ('Bengaluru'))

# %%
Data.isnull().sum()
Data = Data[(Data['Job Role']!=0) & (Data['Skills']!=0) & (Data['Location']!=0) ]

# %%
Data = Data.fillna(0)
Data.shape
# Out:
# (90, 3)

# %%
print("Unique Skills:", Data['Skills'].unique())
print("Unique Job Titles:", Data['Job Role'].unique())
print("Unique Location:", Data['Location'].unique())
# Out:
# Unique Skills: ['Sklearn' 'Data Wrangling' 'Keras' 'PyTorch' 'Machine Learning'
#  'Tensorflow' 'Data Analysis' 'Analyst' 'Publishing' 'Architechture'
#  'Data Science' 'Consulting' 'Business Administration'
#  'Process Orientation' 'Artificial  Intellegence' 'Java' 'Python'
#  'R Shiny' 'Programmimng' 'Spark' 'Ggplot' 'Linux' 'Scala' 'NoSQL'
#  'Pentaho' 'R Julia' 'SQL' 'Predictive Modeling' 'R' 'Risk Analytics'
#  'Statistical Modeling' 'Risk Modeling' 'Multivariate Analysis'
#  'Retail Sales' 'Factor Analysis' 'Marketing Mix Modeling' 'PySpark'
#  'Mesos' 'Communication' 'Logstash' 'Management Reporting'
#  'Written Communication' 'Computer Science' 'Logistic Regression'
#  'Operation Research' 'Cloud' 'NLP' 'Deep Learning' 'Image Processing'
#  'Hadoop' 'Decision Tree' 'GBM' 'Multiple Linear Regression' 'Tableau'
#  'Azure Data Factory' 'Algorithm' 'Django' 'Web Technologies' 'MongoDB'
#  'Automation' 'Big Data' 'Statistical Analysis' 'Agile' 'Spunk' 'Oracle']
# ...

# %%
plt.rcParams['figure.figsize'] = (20, 10)
pd.crosstab(Data['Skills'],Data['Location']).plot(kind = 'bar' , stacked = True)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 10)
pd.crosstab(Data['Job Role'],Data['Skills']).plot(kind = 'bar' , stacked = True)
plt.show()
# Out:
# c:\users\joy\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 150 missing from current font.
#
# c:\users\joy\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning:
#
# Glyph 150 missing from current font.

# %%
sns.countplot(Data['Skills'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# c:\users\joy\appdata\local\programs\python\python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot(Data['Location'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# c:\users\joy\appdata\local\programs\python\python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot(Data['Job Role'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# c:\users\joy\appdata\local\programs\python\python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# c:\users\joy\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 150 missing from current font.
#
# c:\users\joy\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning:
#
# Glyph 150 missing from current font.

# %%
Data['Skills'].value_counts().head(20)
# Out:
# Data Science                6
# Machine Learning            6
# Python                      5
# Artificial  Intellegence    3
# Analyst                     3
# Scala                       2
# Spark                       2
# Deep Learning               2
# R                           2
# Tensorflow                  2
# Computer Science            2
# Data Analysis               2
# Management Reporting        1
# Tableau                     1
# Logistic Regression         1
# Spunk                       1
# Oracle                      1
# Java                        1
# NoSQL                       1
# R Shiny                     1
# Name: Skills, dtype: int64

# %%
Data['Job Role'].value_counts()
# Out:
# Senior Analyst-Data Science                                   9
# Mentor - Data Analyst/Data Science                            7
# Data Science                                                  7
# Analyst/Senior Analyst/Assistant Manager - Data Science       7
# Data Science Intern                                           7
# Data Science Engineer                                         7
# Data Scientist/Data science Engineer                          6
# Deputy Manager - Analytics - Retail - Data Sciences           5
# Sr Specialist/ Expert - Data Science                          5
# Data Science Team Lead                                        5
# Data Analyst - Data Science & Analytics                       5
# Assistant Trainer - Web Development/Data Science              5
# Data Scientist                                                5
# Data Science Analyst                                          4
# Analyst  Data Science                                        4
# ...

# %%
Data['Location'].value_counts()
# Out:
# Bengaluru    31
# Hyderabad    20
# Mumbai       15
# Chennai      10
# Pune          7
# Kolkata       7
# Name: Location, dtype: int64

# %% [markdown]
# # Based on The Research The Following can be stated
#
# 1. The Most Important on Demand Skills to have in resume is
# Data Science
# Machine Learning
# Python
# Artificial  Intellegence
# Analyst
# Scala
# Spark
# Deep Learning
# R
# Tensorflow
# Computer Science
# Data Analysis
#
# 2. The Most Preferred Location For Data Science Jobs are -
#
# Bengaluru
# Hyderabad
# Mumbai
# Chennai
# Pune
# Kolkata
#
# 2. The Most Common Roles For Data Science Jobs are -
#
# Senior Analyst-Data Science
# Mentor - Data Analyst/Data Science
# Data Science
# Analyst/Senior Analyst/Assistant Manager - Data Science
# Data Science Intern
# Data Science Engineer
# Data Scientist/Data science Engineer
# Deputy Manager - Analytics - Retail - Data Sciences
# Sr Specialist/ Expert - Data Science
# Data Science Team Lead
# Data Analyst - Data Science & Analytics
# Assistant Trainer - Web Development/Data Science
# Data Scientist
# Data Science Analyst
# Analyst  Data Science
